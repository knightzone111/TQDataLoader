# %%
import pandas as pd
from datetime import timedelta, datetime
from dateutil.relativedelta import relativedelta
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv("Data\\SHFE.rb\\SHFE.rb2101_tick.csv", index_col = 0)

# %%
dt_index = pd.to_datetime(df.index)

# %%
df.set_index(dt_index, inplace = True)

# %%
df = df.loc["2020-01-16 09:00:00": "2020-01-16 23:59:59"]

# %%
df
# Out:
#                          last_price  highest  lowest  bid_price1  bid_volume1  \
# datetime
# 2020-01-16 09:00:00.500      3291.0   3291.0  3241.0      3287.0           46
# 2020-01-16 09:00:01.000      3287.0   3291.0  3241.0      3287.0           44
# 2020-01-16 09:00:01.500      3291.0   3291.0  3241.0      3291.0            5
# 2020-01-16 09:00:02.000      3291.0   3291.0  3241.0      3291.0           16
# 2020-01-16 09:00:02.500      3291.0   3291.0  3241.0      3291.0            3
# 2020-01-16 09:00:03.000      3291.0   3291.0  3241.0      3288.0            1
# 2020-01-16 09:00:03.500      3288.0   3291.0  3241.0      3288.0           14
# 2020-01-16 09:00:04.500      3288.0   3291.0  3241.0      3288.0           15
# 2020-01-16 09:00:05.000      3288.0   3291.0  3241.0      3291.0            2
# 2020-01-16 09:00:05.500      3292.0   3292.0  3241.0      3291.0            2
# 2020-01-16 09:00:06.000      3291.0   3292.0  3241.0      3288.0           15
# ...

# %%
df_clean = df.resample('1s').first().fillna(method = "ffill")

# %%
df_clean['last_price'].plot(figsize = (20,10))

# %%
df_clean
# Out:
#                      last_price  highest  lowest  bid_price1  bid_volume1  \
# datetime
# 2020-01-16 09:00:00      3291.0   3291.0  3241.0      3287.0         46.0
# 2020-01-16 09:00:01      3287.0   3291.0  3241.0      3287.0         44.0
# 2020-01-16 09:00:02      3291.0   3291.0  3241.0      3291.0         16.0
# 2020-01-16 09:00:03      3291.0   3291.0  3241.0      3288.0          1.0
# 2020-01-16 09:00:04      3288.0   3291.0  3241.0      3288.0         15.0
# 2020-01-16 09:00:05      3288.0   3291.0  3241.0      3291.0          2.0
# 2020-01-16 09:00:06      3291.0   3292.0  3241.0      3288.0         15.0
# 2020-01-16 09:00:07      3291.0   3292.0  3241.0      3288.0         15.0
# 2020-01-16 09:00:08      3291.0   3292.0  3241.0      3288.0         20.0
# 2020-01-16 09:00:09      3291.0   3292.0  3241.0      3288.0         20.0
# 2020-01-16 09:00:10      3291.0   3292.0  3241.0      3288.0         20.0
# ...

# %%
# ?df.asfreq

# %%
df.head()
# Out:
#                          last_price  highest  lowest  bid_price1  bid_volume1  \
# datetime
# 2020-01-16 09:00:00.500      3291.0   3291.0  3241.0      3287.0           46
# 2020-01-16 09:00:01.000      3287.0   3291.0  3241.0      3287.0           44
# 2020-01-16 09:00:01.500      3291.0   3291.0  3241.0      3291.0            5
# 2020-01-16 09:00:02.000      3291.0   3291.0  3241.0      3291.0           16
# 2020-01-16 09:00:02.500      3291.0   3291.0  3241.0      3291.0            3
#
#                          ask_price1  ask_volume1  volume       amount  \
# datetime
# 2020-01-16 09:00:00.500      3291.0            7   22020  721940440.0
# 2020-01-16 09:00:01.000      3291.0            5   22024  722072000.0
# 2020-01-16 09:00:01.500      3292.0            2   22029  722236550.0
# 2020-01-16 09:00:02.000      3292.0            4   22030  722269460.0
# 2020-01-16 09:00:02.500      3292.0            4   22043  722697290.0
#
#                          open_interest
# datetime
# ...

# %%
bench_index = pd.date_range("2020-01-16 09:00:00", "2020-01-16 23:59:59", freq = "s")

# %%
data = np.full(len(bench_index), np.nan)

# %%
data
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
bench_index
# Out:
# DatetimeIndex(['2020-01-16 09:00:00', '2020-01-16 09:00:01',
#                '2020-01-16 09:00:02', '2020-01-16 09:00:03',
#                '2020-01-16 09:00:04', '2020-01-16 09:00:05',
#                '2020-01-16 09:00:06', '2020-01-16 09:00:07',
#                '2020-01-16 09:00:08', '2020-01-16 09:00:09',
#                ...
#                '2020-01-16 23:59:50', '2020-01-16 23:59:51',
#                '2020-01-16 23:59:52', '2020-01-16 23:59:53',
#                '2020-01-16 23:59:54', '2020-01-16 23:59:55',
#                '2020-01-16 23:59:56', '2020-01-16 23:59:57',
#                '2020-01-16 23:59:58', '2020-01-16 23:59:59'],
#               dtype='datetime64[ns]', length=54000, freq='S')

# %%
for t, value in df.iterrows():
    for i in range(len(bench_index)):
        if t.time() == bench_index[i].time():
            data[i] = value['last_price']
            break
        else:
            continue

# %%
data
# Out:
# array([  nan, 3287., 3291., ...,   nan,   nan,   nan])

# %%
ds = pd.Series(data, index = bench_index)

# %%
ds.plot(figsize = (20,10))

# %%
for x, y in df.iterrows():
    print(y)
# Out:
# last_price       NaN
# highest          NaN
# lowest           NaN
# bid_price1       NaN
# bid_volume1      0.0
# ask_price1       NaN
# ask_volume1      0.0
# volume           0.0
# amount           0.0
# open_interest    0.0
# Name: 2020-01-15 18:49:20.600, dtype: float64
# last_price          3281.0
# highest             3281.0
# lowest              3281.0
# bid_price1          3281.0
# bid_volume1           89.0
# ask_price1          3285.0
# ask_volume1           10.0
# volume                47.0
# amount           1542070.0
# open_interest         47.0
# Name: 2020-01-15 20:59:00.500, dtype: float64
# last_price          3290.0
# highest             3290.0
# lowest              3281.0
# bid_price1          3285.0
# bid_volume1            1.0
# ask_price1          3290.0
# ask_volume1          171.0
# volume               105.0
# amount           3449750.0
# open_interest        105.0
# Name: 2020-01-15 21:00:00.500, dtype: float64
# last_price          3281.0
# ...

# %%
df_index = [pd.to_datetime(x).time() for x in df.index]

# %%
df_index
# Out:
# [datetime.time(18, 49, 20, 600000),
#  datetime.time(20, 59, 0, 500000),
#  datetime.time(21, 0, 0, 500000),
#  datetime.time(21, 0, 1),
#  datetime.time(21, 0, 1, 500000),
#  datetime.time(21, 0, 2),
#  datetime.time(21, 0, 2, 500000),
#  datetime.time(21, 0, 3),
#  datetime.time(21, 0, 3, 500000),
#  datetime.time(21, 0, 4),
#  datetime.time(21, 0, 4, 500000),
#  datetime.time(21, 0, 5),
#  datetime.time(21, 0, 5, 500000),
#  datetime.time(21, 0, 6),
#  datetime.time(21, 0, 7),
#  datetime.time(21, 0, 7, 500000),
#  datetime.time(21, 0, 8),
#  datetime.time(21, 0, 8, 500000),
#  datetime.time(21, 0, 9),
#  datetime.time(21, 0, 9, 500000),
#  datetime.time(21, 0, 10, 500000),
#  datetime.time(21, 0, 11, 500000),
#  datetime.time(21, 0, 12),
#  datetime.time(21, 0, 12, 500000),
#  datetime.time(21, 0, 13),
#  datetime.time(21, 0, 13, 500000),
#  datetime.time(21, 0, 14),
#  datetime.time(21, 0, 14, 500000),
#  datetime.time(21, 0, 15),
#  datetime.time(21, 0, 15, 500000),
# ...

# %%
timeindex.time
# Out:
# array([datetime.time(9, 0), datetime.time(9, 0, 1),
#        datetime.time(9, 0, 2), ..., datetime.time(23, 58, 58),
#        datetime.time(23, 58, 59), datetime.time(23, 59)], dtype=object)

# %%
mask = [t for t in timeindex.time]

# %%
value = []
for x in mask:
    if x in df_index:
        value.append()

# %%
value
# Out:
# [datetime.time(9, 0, 1),
#  datetime.time(9, 0, 2),
#  datetime.time(9, 0, 3),
#  datetime.time(9, 0, 5),
#  datetime.time(9, 0, 6),
#  datetime.time(9, 0, 9),
#  datetime.time(9, 0, 11),
#  datetime.time(9, 0, 15),
#  datetime.time(9, 0, 16),
#  datetime.time(9, 0, 17),
#  datetime.time(9, 0, 19),
#  datetime.time(9, 0, 20),
#  datetime.time(9, 0, 21),
#  datetime.time(9, 0, 23),
#  datetime.time(9, 0, 24),
#  datetime.time(9, 0, 25),
#  datetime.time(9, 0, 26),
#  datetime.time(9, 0, 27),
#  datetime.time(9, 0, 28),
#  datetime.time(9, 0, 31),
#  datetime.time(9, 0, 33),
#  datetime.time(9, 0, 34),
#  datetime.time(9, 0, 35),
#  datetime.time(9, 0, 36),
#  datetime.time(9, 0, 38),
#  datetime.time(9, 0, 39),
#  datetime.time(9, 0, 40),
#  datetime.time(9, 0, 41),
#  datetime.time(9, 0, 42),
#  datetime.time(9, 0, 43),
#  datetime.time(9, 0, 44),
#  datetime.time(9, 0, 47),
#  datetime.time(9, 0, 48),
#  datetime.time(9, 0, 51),
#  datetime.time(9, 0, 53),
# ...

# %%
df.loc['2020-01-15 21:00:00']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [2020-01-15 21:00:00] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-5ddb4c278ebf> in <module>()
# ----> 1 df.loc['2020-01-15 21:00:00']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %%
mask
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...
