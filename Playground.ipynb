# %%
import pandas as pd
import DataLoader as dl
# Out:
# 在使用天勤量化之前，默认您已经知晓并同意以下免责条款，如果不同意请立即停止使用：https://www.shinnytech.com/blog/disclaimer/

# %%
# x: different months contract 
# y: value 

syms = dl.get_recent_symbols("2020-06-21", "SHFE.rb", 12)

# %%
print(syms)
# Out:
# ['SHFE.rb2006', 'SHFE.rb2007', 'SHFE.rb2008', 'SHFE.rb2009', 'SHFE.rb2010', 'SHFE.rb2011', 'SHFE.rb2012', 'SHFE.rb2101', 'SHFE.rb2102', 'SHFE.rb2103', 'SHFE.rb2104', 'SHFE.rb2105']

# %%
data = {}
for sym in syms:
    data[sym] = dl.read_data(sym, 'D', None, None)
# Out:
# Data\SHFE.rb\SHFE.rb2006_D.csv
# Data\SHFE.rb\SHFE.rb2007_D.csv
# Data\SHFE.rb\SHFE.rb2008_D.csv
# Data\SHFE.rb\SHFE.rb2009_D.csv
# Data\SHFE.rb\SHFE.rb2010_D.csv
# Data\SHFE.rb\SHFE.rb2011_D.csv
# Data\SHFE.rb\SHFE.rb2012_D.csv
# Data\SHFE.rb\SHFE.rb2101_D.csv
# Data\SHFE.rb\SHFE.rb2102_D.csv
# Data\SHFE.rb\SHFE.rb2103_D.csv
# Data\SHFE.rb\SHFE.rb2104_D.csv
# Data\SHFE.rb\SHFE.rb2105_D.csv

# %%
tds = pd.date_range("2020-01-05", "2020-06-21")

# %%
prices = {}
for td in tds:
    td = str(td.date())
    price_day = {}
    for sym in syms:
        try:
            price_day[sym] = (data[sym].loc[td][sym+'.close'])
        except Exception as inst:
            print(inst)
    if price_day:
        prices[td] = price_day
# Out:
# '2020-01-05'
# '2020-01-05'
# '2020-01-05'
# '2020-01-05'
# '2020-01-05'
# '2020-01-05'
# '2020-01-05'
# '2020-01-05'
# '2020-01-05'
# '2020-01-05'
# '2020-01-05'
# '2020-01-05'
# '2020-01-06'
# '2020-01-06'
# '2020-01-06'
# '2020-01-06'
# '2020-01-06'
# '2020-01-07'
# '2020-01-07'
# '2020-01-07'
# '2020-01-07'
# '2020-01-07'
# '2020-01-08'
# '2020-01-08'
# '2020-01-08'
# '2020-01-08'
# '2020-01-08'
# '2020-01-09'
# '2020-01-09'
# '2020-01-09'
# '2020-01-09'
# '2020-01-09'
# '2020-01-10'
# '2020-01-10'
# '2020-01-10'
# '2020-01-10'
# '2020-01-10'
# '2020-01-11'
# '2020-01-11'
# '2020-01-11'
# '2020-01-11'
# '2020-01-11'
# '2020-01-11'
# '2020-01-11'
# '2020-01-11'
# '2020-01-11'
# '2020-01-11'
# '2020-01-11'
# '2020-01-11'
# '2020-01-12'
# '2020-01-12'
# '2020-01-12'
# '2020-01-12'
# '2020-01-12'
# '2020-01-12'
# '2020-01-12'
# '2020-01-12'
# '2020-01-12'
# '2020-01-12'
# '2020-01-12'
# '2020-01-12'
# '2020-01-13'
# '2020-01-13'
# '2020-01-13'
# '2020-01-13'
# '2020-01-13'
# ...

# %%
prices
# Out:
# {'2020-01-06': {'SHFE.rb2006': 3460.0,
#   'SHFE.rb2007': 3444.0,
#   'SHFE.rb2008': 3469.0,
#   'SHFE.rb2009': 3441.0,
#   'SHFE.rb2010': 3397.0,
#   'SHFE.rb2011': 3355.0,
#   'SHFE.rb2012': 3342.0},
#  '2020-01-07': {'SHFE.rb2006': 3476.0,
#   'SHFE.rb2007': 3458.0,
#   'SHFE.rb2008': 3481.0,
#   'SHFE.rb2009': 3456.0,
#   'SHFE.rb2010': 3409.0,
#   'SHFE.rb2011': 3362.0,
#   'SHFE.rb2012': 3350.0},
#  '2020-01-08': {'SHFE.rb2006': 3522.0,
#   'SHFE.rb2007': 3495.0,
#   'SHFE.rb2008': 3514.0,
#   'SHFE.rb2009': 3494.0,
#   'SHFE.rb2010': 3445.0,
#   'SHFE.rb2011': 3389.0,
#   'SHFE.rb2012': 3365.0},
#  '2020-01-09': {'SHFE.rb2006': 3475.0,
#   'SHFE.rb2007': 3460.0,
#   'SHFE.rb2008': 3479.0,
#   'SHFE.rb2009': 3449.0,
#   'SHFE.rb2010': 3393.0,
#   'SHFE.rb2011': 3351.0,
#   'SHFE.rb2012': 3328.0},
#  '2020-01-10': {'SHFE.rb2006': 3488.0,
#   'SHFE.rb2007': 3476.0,
#   'SHFE.rb2008': 3499.0,
#   'SHFE.rb2009': 3459.0,
#   'SHFE.rb2010': 3409.0,
#   'SHFE.rb2011': 3363.0,
# ...

# %%
df = pd.DataFrame(prices)

# %%
ds = df['2020-06-05']

# %%
ds.plot(figsize = (20,10))
